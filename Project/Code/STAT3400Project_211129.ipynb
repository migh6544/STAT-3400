# %%
MPI <- read.csv("C:/Users/chank/Downloads/MPI.xlsx - MPI.csv")
GDP <- read.csv("C:/Users/chank/Downloads/GDP.xlsx - GDP.csv")
GDP <- GDP[,2:11]
MPI <- MPI[,2:6]
GDP <- as.matrix(t(GDP))
MPI <- as.matrix(t(MPI))
head(GDP)
head(MPI)
# Out:
#        [,1]     [,2]     [,3]     [,4]     [,5]     [,6]     [,7]     [,8]
# Year.1 1.15e+11 2.16e+10 5.39e+10 2.71e+10 2.23e+09 6.96e+09 7.19e+09 9.32e+10
# Year.2 1.29e+11 2.58e+10 5.80e+10 2.95e+10 2.58e+09 8.00e+09 1.04e+10 1.01e+11
# Year.3 1.33e+11 2.93e+10 6.07e+10 3.16e+10 2.48e+09 6.03e+09 1.23e+10 9.83e+10
# Year.4 1.50e+11 3.27e+10 6.27e+10 3.45e+10 2.37e+09 5.52e+09 1.26e+10 1.07e+11
# Year.5 1.73e+11 3.59e+10 6.72e+10 3.68e+10 2.44e+09 6.05e+09 1.22e+10 1.10e+11
# Year.6 1.95e+11 3.79e+10 7.12e+10 3.86e+10 2.36e+09 6.37e+09 1.17e+10 1.01e+11
#        [,9]     [,10]    [,11]    [,12]    [,13]    [,14]    [,15]    [,16]
# Year.1 3.61e+11 1.48e+11 2.08e+11 1.61e+10 2.58e+09 3.75e+11 4.37e+09 3.43e+09
# Year.2 4.05e+11 1.72e+11 2.34e+11 1.78e+10 2.94e+09 4.16e+11 4.42e+09 3.87e+09
# Year.3 4.56e+11 1.93e+11 2.62e+11 1.77e+10 3.80e+09 3.96e+11 4.98e+09 3.87e+09
# Year.4 5.09e+11 2.01e+11 2.84e+11 1.89e+10 4.92e+09 3.67e+11 5.15e+09 4.32e+09
# ...

# %%
Bangladesh_MPI<-data.frame(MPI[,1])
Bangladesh_MPI<-as.matrix(t(Bangladesh_MPI))
hist(Bangladesh_MPI)
D.R.Congo_MPI<-data.frame(MPI[,2])
D.R.Congo_MPI<-as.matrix(t(D.R.Congo_MPI))
hist(D.R.Congo_MPI)
Dominican_Republic_MPI<-data.frame(MPI[,3])
Dominican_Republic_MPI<-as.matrix(t(Dominican_Republic_MPI))
hist(Dominican_Republic_MPI)
Jordan_MPI<-data.frame(MPI[,4])
Jordan_MPI<-as.matrix(t(Jordan_MPI))
hist(Jordan_MPI)
Lesotho_MPI<-data.frame(MPI[,5])
Lesotho_MPI<-as.matrix(t(Lesotho_MPI))
hist(Lesotho_MPI)
Malawi_MPI<-data.frame(MPI[,6])
Malawi_MPI<-as.matrix(t(Malawi_MPI))
hist(Malawi_MPI)
Mongolia_MPI<-data.frame(MPI[,7])
Mongolia_MPI<-as.matrix(t(Mongolia_MPI))
hist(Mongolia_MPI)
Morocco_MPI<-data.frame(MPI[,8])
Morocco_MPI<-as.matrix(t(Morocco_MPI))
hist(Morocco_MPI)
Nigeria_MPI<-data.frame(MPI[,9])
Nigeria_MPI<-as.matrix(t(Nigeria_MPI))
hist(Nigeria_MPI)
Peru_MPI<-data.frame(MPI[,10])
Peru_MPI<-as.matrix(t(Peru_MPI))
hist(Peru_MPI)
Philippines_MPI <-data.frame(MPI[,11])
Philippines_MPI<-as.matrix(t(Philippines_MPI))
hist(Philippines_MPI)
Senegal_MPI<-data.frame(MPI[,12])
Senegal_MPI<-as.matrix(t(Senegal_MPI))
hist(Senegal_MPI)
Sierra_Leone_MPI<-data.frame(MPI[,13])
Sierra_Leone_MPI<-as.matrix(t(Sierra_Leone_MPI))
hist(Sierra_Leone_MPI)
South_Africa_MPI<-data.frame(MPI[,14])
South_Africa_MPI<-as.matrix(t(South_Africa_MPI))
hist(South_Africa_MPI)
Suriname_MPI<-data.frame(MPI[,15])
Suriname_MPI<-as.matrix(t(Suriname_MPI))
hist(Suriname_MPI)
Togo_MPI<-data.frame(MPI[,16])
Togo_MPI<-as.matrix(t(Togo_MPI))
hist(Togo_MPI)
Zimbabwe_MPI <-data.frame(MPI[,17])
Zimbabwe_MPI<-as.matrix(t(Zimbabwe_MPI))
hist(Zimbabwe_MPI)
# Out:
# Plot with title "Histogram of Bangladesh_MPI"
# Plot with title "Histogram of D.R.Congo_MPI"
# Plot with title "Histogram of Dominican_Republic_MPI"
# Plot with title "Histogram of Jordan_MPI"
# Plot with title "Histogram of Lesotho_MPI"
# Plot with title "Histogram of Malawi_MPI"
# Plot with title "Histogram of Mongolia_MPI"
# Plot with title "Histogram of Morocco_MPI"
# Plot with title "Histogram of Nigeria_MPI"
# Plot with title "Histogram of Peru_MPI"
# Plot with title "Histogram of Philippines_MPI"
# Plot with title "Histogram of Senegal_MPI"
# Plot with title "Histogram of Sierra_Leone_MPI"
# Plot with title "Histogram of South_Africa_MPI"
# Plot with title "Histogram of Suriname_MPI"
# Plot with title "Histogram of Togo_MPI"
# Plot with title "Histogram of Zimbabwe_MPI"

# %%
Bangladesh_GDP<-data.frame(GDP[,1])
Bangladesh_GDP<-as.matrix(t(Bangladesh_GDP))
hist(Bangladesh_GDP)
D.R.Congo_GDP<-data.frame(GDP[,2])
D.R.Congo_GDP<-as.matrix(t(D.R.Congo_GDP))
hist(D.R.Congo_GDP)
Dominican_Republic_GDP<-data.frame(GDP[,3])
Dominican_Republic_GDP<-as.matrix(t(Dominican_Republic_GDP))
hist(Dominican_Republic_GDP)
Jordan_GDP<-data.frame(GDP[,4])
Jordan_GDP<-as.matrix(t(Jordan_GDP))
hist(Jordan_GDP)
Lesotho_GDP<-data.frame(GDP[,5])
Lesotho_GDP<-as.matrix(t(Lesotho_GDP))
hist(Lesotho_GDP)
Malawi_GDP<-data.frame(GDP[,6])
Malawi_GDP<-as.matrix(t(Malawi_GDP))
hist(Malawi_GDP)
Mongolia_GDP<-data.frame(GDP[,7])
Mongolia_GDP<-as.matrix(t(Mongolia_GDP))
hist(Mongolia_GDP)
Morocco_GDP<-data.frame(GDP[,8])
Morocco_GDP<-as.matrix(t(Morocco_GDP))
hist(Morocco_GDP)
Nigeria_GDP<-data.frame(GDP[,9])
Nigeria_GDP<-as.matrix(t(Nigeria_GDP))
hist(Nigeria_GDP)
Peru_GDP<-data.frame(GDP[,10])
Peru_GDP<-as.matrix(t(Peru_GDP))
hist(Peru_GDP)
Philippines_GDP <-data.frame(GDP[,11])
Philippines_GDP<-as.matrix(t(Philippines_GDP))
hist(Philippines_GDP)
Senegal_GDP<-data.frame(GDP[,12])
Senegal_GDP<-as.matrix(t(Senegal_GDP))
hist(Senegal_GDP)
Sierra_Leone_GDP<-data.frame(GDP[,13])
Sierra_Leone_GDP<-as.matrix(t(Sierra_Leone_GDP))
hist(Sierra_Leone_GDP)
South_Africa_GDP<-data.frame(GDP[,14])
South_Africa_GDP<-as.matrix(t(South_Africa_GDP))
hist(South_Africa_GDP)
Suriname_GDP<-data.frame(GDP[,15])
Suriname_GDP<-as.matrix(t(Suriname_GDP))
hist(Suriname_GDP)
Togo_GDP<-data.frame(GDP[,16])
Togo_GDP<-as.matrix(t(Togo_GDP))
hist(Togo_GDP)
Zimbabwe_GDP <-data.frame(GDP[,17])
Zimbabwe_GDP<-as.matrix(t(Zimbabwe_GDP))
hist(Zimbabwe_GDP)
# Out:
# Plot with title "Histogram of Bangladesh_GDP"
# Plot with title "Histogram of D.R.Congo_GDP"
# Plot with title "Histogram of Dominican_Republic_GDP"
# Plot with title "Histogram of Jordan_GDP"
# Plot with title "Histogram of Lesotho_GDP"
# Plot with title "Histogram of Malawi_GDP"
# Plot with title "Histogram of Mongolia_GDP"
# Plot with title "Histogram of Morocco_GDP"
# Plot with title "Histogram of Nigeria_GDP"
# Plot with title "Histogram of Peru_GDP"
# Plot with title "Histogram of Philippines_GDP"
# Plot with title "Histogram of Senegal_GDP"
# Plot with title "Histogram of Sierra_Leone_GDP"
# Plot with title "Histogram of South_Africa_GDP"
# Plot with title "Histogram of Suriname_GDP"
# Plot with title "Histogram of Togo_GDP"
# Plot with title "Histogram of Zimbabwe_GDP"

# %%
Bang_10y<-mean(Bangladesh_GDP)
D.RCon_10y<-mean(D.R.Congo_GDP)
Dom_10y_G<-mean(Dominican_Republic_GDP)
Jor_10y<-mean(Jordan_GDP)
Les_10y<-mean(Lesotho_GDP)
Mwl_10y<-mean(Malawi_GDP)
Mgl_10y<-mean(Mongolia_GDP)
Mrc_10y<-mean(Morocco_GDP)
Nga_10y<-mean(Nigeria_GDP)
Peru_10y_G<-mean(Peru_GDP)
Phi_10y_G<-mean(Philippines_GDP)
Sen_10y_G<-mean(Senegal_GDP)
Sie_10y_G<-mean(Sierra_Leone_GDP)
RSA_10y_G<-mean(South_Africa_GDP)
SME_10y_G<-mean(Suriname_GDP)
Togo_10y_G<-mean(Togo_GDP)
Zim_10y_G<-mean(Zimbabwe_GDP)

# %%
Bangladesh_10y<-mean(Bangladesh_MPI)
D.R.Congo_10y<-mean(D.R.Congo_MPI)
Dom_10y<-mean(Dominican_Republic_MPI)
Jordan_10y<-mean(Jordan_MPI)
Lesotho_10y<-mean(Lesotho_MPI)
Malawi_10y<-mean(Malawi_MPI)
Mongol_10y<-mean(Mongolia_MPI)
MOR_10y<-mean(Morocco_MPI)
Nigeria_10y<-mean(Nigeria_MPI)
Peru_10y<-mean(Peru_MPI)
Phil_10y<-mean(Philippines_MPI)
Sen_10y<-mean(Senegal_MPI)
Sie_10y<-mean(Sierra_Leone_MPI)
Sou_10y<-mean(South_Africa_MPI)
Sur_10y<-mean(Suriname_MPI)
Togo_10y<-mean(Togo_MPI)
Zim_10y<-mean(Zimbabwe_MPI)

# %%
MPI_10Year_Mean_Total <- cbind(c(Bangladesh_10y,D.R.Congo_10y,Dom_10y,Jordan_10y,Lesotho_10y,Malawi_10y,Mongol_10y,MOR_10y,Nigeria_10y,Peru_10y,Phil_10y,Sen_10y,Sie_10y,Sou_10y,Sur_10y,Togo_10y,Zim_10y))

# %%
MPI_10Year_Mean_Total
# Out:
#       [,1]
#  [1,] 0.2218
#  [2,] 0.3790
#  [3,] 0.0272
#  [4,] 0.0062
#  [5,] 0.1492
#  [6,] 0.2950
#  [7,] 0.0428
#  [8,] 0.0774
#  [9,] 0.3030
# [10,] 0.0552
# [11,] 0.0490
# [12,] 0.3590
# [13,] 0.4404
# [14,] 0.0344
# [15,] 0.0318
# [16,] 0.2432
# [17,] 0.1560

# %%
hist(MPI_10Year_Mean_Total)
dens = density(MPI_10Year_Mean_Total)
lines(dens$x,dens$y,col=2)
# Out:
# Plot with title "Histogram of MPI_10Year_Mean_Total"

# %%
GDP_10Year_Mean_Total
# Out:
#       [,1]
#  [1,] 1.9430e+11
#  [2,] 3.5550e+10
#  [3,] 7.0390e+10
#  [4,] 3.6680e+10
#  [5,] 2.3760e+09
#  [6,] 7.3760e+09
#  [7,] 1.1609e+10
#  [8,] 1.0615e+11
#  [9,] 4.3910e+11
# [10,] 1.9590e+11
# [11,] 2.9620e+11
# [12,] 1.9450e+10
# [13,] 3.9100e+09
# [14,] 3.5880e+11
# [15,] 4.4420e+09
# [16,] 5.1000e+09
# [17,] 1.7770e+10

# %%
GDP_10Year_Mean_Total<-cbind(c(Bang_10y,D.RCon_10y,Dom_10y_G,Jor_10y,Les_10y,Mwl_10y,Mgl_10y,Mrc_10y,Nga_10y,Peru_10y_G,Phi_10y_G,Sen_10y_G,Sie_10y_G,RSA_10y_G,SME_10y_G,Togo_10y_G,Zim_10y_G))

# %%
hist(GDP_10Year_Mean_Total)
dens = density(GDP_10Year_Mean_Total)
lines(dens$x,dens$y,col=2)
# Out:
# Plot with title "Histogram of GDP_10Year_Mean_Total"

# %%
Data <- cbind(GDP_10Year_Mean_Total, MPI_10Year_Mean_Total)
colnames(Data) <- c('GDP', 'MPI')
data <- as.data.frame(Data)

# %%
GDP_Mean <- mean(data$GDP)
GDP_Var <- var(data$GDP)
GDP_Mean
GDP_Var
t.test(data$GDP)

MPI_mean <- mean(data$MPI)
MPI_Var <- var(data$MPI)
MPI_mean
MPI_Var
t.test(data$GDP)
# Out:
# [1] 106182529412
# [1] 1.959508e+22
# 	One Sample t-test
#
# data:  data$GDP
# t = 3.1275, df = 16, p-value = 0.006494
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#   34210202799 178154856025
# sample estimates:
#    mean of x
# 106182529412
# [1] 0.1688588
# [1] 0.02073523
# 	One Sample t-test
#
# data:  data$GDP
# t = 3.1275, df = 16, p-value = 0.006494
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#   34210202799 178154856025
# sample estimates:
#    mean of x
# 106182529412

# %%
lmodMPI = lm(MPI ~ GDP, data = data)
summary(lmodMPI)
plot(lmodMPI)

lmodGDP = lm(GDP ~ MPI, data = data)
summary(lmodGDP)
plot(lmodGDP)
# Out:
# Call:
# lm(formula = MPI ~ GDP, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.17403 -0.09899 -0.03664  0.10998  0.25481
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.862e-01  4.520e-02   4.120 0.000909 ***
# GDP         -1.636e-13  2.622e-13  -0.624 0.542187
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.1468 on 15 degrees of freedom
# Multiple R-squared:  0.02528,	Adjusted R-squared:  -0.0397
# F-statistic: 0.389 on 1 and 15 DF,  p-value: 0.5422
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Call:
# lm(formula = GDP ~ MPI, data = data)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -1.229e+11 -9.040e+10 -5.769e+10  7.215e+10  3.537e+11
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.323e+11  5.431e+10   2.436   0.0278 *
# ...
